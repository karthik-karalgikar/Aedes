# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-karalgikar/Aedes/blob/main/VGG16epoch50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'  'Dataset_Segmentation '

# %%
batch_size = 64
size = (224,224)

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Dataset_Segmentation ",
    batch_size=batch_size,
    image_size=size,
    validation_split=0.2,
    subset="training",
    seed=123
)


ds_train = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Dataset_Segmentation ",
    validation_split = 0.2,
    subset = "training",
    seed = 123)


ds_validation = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Dataset_Segmentation ",
    validation_split = 0.2,
    subset = "validation",
    seed = 123)
# Out:
# Found 664 files belonging to 2 classes.
# Using 532 files for training.
# Found 664 files belonging to 2 classes.
# Using 532 files for training.
# Found 664 files belonging to 2 classes.
# Using 132 files for validation.

# %%
import tensorflow_datasets as tdfs

batch_size = 32

dataset_name = dataset
class_names = dataset.class_names
num_classes = len(class_names)
print(class_names)

def preprocess_image_label(image, label):
    image = tf.image.resize(image, size)
    # Convert label to one-hot encoding
    label = tf.one_hot(tf.cast(label, tf.int32), depth=num_classes)
    return image, label

ds_train_encoded = ds_train.map(preprocess_image_label)
ds_validation_encoded = ds_validation.map(preprocess_image_label)
# Out:
# ['Testing', 'Training']

# %%
for image, label in ds_train_encoded.take(1):  # Taking one batch for example
    print("Image shape:", image.shape)
    print("Label shape:", label.shape)
# Out:
# Image shape: (32, 224, 224, 3)
# Label shape: (32, 2)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for images, label in ds_train.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[label[i]])
    plt.axis("off")

# %%
# size = (224,224)

# ds_train_resized = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
# ds_validation_resized = ds_validation.map(lambda image, label: (tf.image.resize(image, size), label))

# %%
# Iterate over the dataset and print the shape of the first batch
for image, label in ds_train_encoded.take(1):
    print("Shape of images in ds_train_encoded:", image.shape)
    print("Shape of labels in ds_train_encoded:", label.shape)

for image, label in ds_validation_encoded.take(1):
    print("Shape of images in ds_validation_encoded:", image.shape)
    print("Shape of labels in ds_validation_encoded:", label.shape)
# Out:
# Shape of images in ds_train_encoded: (32, 224, 224, 3)
# Shape of labels in ds_train_encoded: (32, 2)
# Shape of images in ds_validation_encoded: (32, 224, 224, 3)
# Shape of labels in ds_validation_encoded: (32, 2)

# %%
print("Model output shape:", model.output_shape)
# Out:
# Model output shape: (None, 10)

# %%
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import *
import numpy as np

# %%
from keras.callbacks import ModelCheckpoint

# %%
from keras.models import Model

# %%
vgg = VGG16(input_shape = (224, 224, 3), weights= 'imagenet', include_top = False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
for i in vgg.layers:
  i.trainable = False

# %%
x = Flatten()(vgg.output)

# %%
pred = Dense(2, activation= 'sigmoid')(x)

# %%
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
# Define input layer
input_shape = (224, 224, 3)
inputs = tf.keras.Input(shape=(input_shape))

# Add layers using functional API
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(32, activation='relu')(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

model = Model(inputs = vgg.input, outputs = pred)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(ds_train_encoded, qwvalidation_data=ds_validation_encoded, epochs=50)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 371s 22s/step - loss: 2.0668 - accuracy: 0.8026 - val_loss: 4.3388 - val_accuracy: 0.7045
# Epoch 2/50
# 17/17 [==============================] - 369s 22s/step - loss: 2.2221 - accuracy: 0.7970 - val_loss: 4.5349 - val_accuracy: 0.7197
# Epoch 3/50
# 17/17 [==============================] - 368s 22s/step - loss: 2.4692 - accuracy: 0.7876 - val_loss: 4.1514 - val_accuracy: 0.7500
# Epoch 4/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.7677 - accuracy: 0.7763 - val_loss: 5.2208 - val_accuracy: 0.6818
# Epoch 5/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.7183 - accuracy: 0.7914 - val_loss: 4.7609 - val_accuracy: 0.6894
# Epoch 6/50
# 17/17 [==============================] - 367s 22s/step - loss: 2.1022 - accuracy: 0.7820 - val_loss: 4.0651 - val_accuracy: 0.7045
# Epoch 7/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.3746 - accuracy: 0.7801 - val_loss: 4.4092 - val_accuracy: 0.6894
# Epoch 8/50
# 17/17 [==============================] - 354s 21s/step - loss: 2.6075 - accuracy: 0.7763 - val_loss: 4.1244 - val_accuracy: 0.7348
# Epoch 9/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.3123 - accuracy: 0.7895 - val_loss: 6.6186 - val_accuracy: 0.7576
# Epoch 10/50
# 17/17 [==============================] - 365s 21s/step - loss: 3.1333 - accuracy: 0.7857 - val_loss: 5.2009 - val_accuracy: 0.7500
# Epoch 11/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.2354 - accuracy: 0.7989 - val_loss: 4.5238 - val_accuracy: 0.6894
# Epoch 12/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.2756 - accuracy: 0.8008 - val_loss: 4.5439 - val_accuracy: 0.7045
# Epoch 13/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.0928 - accuracy: 0.7895 - val_loss: 5.2698 - val_accuracy: 0.7273
# Epoch 14/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.6277 - accuracy: 0.7838 - val_loss: 4.0738 - val_accuracy: 0.7045
# Epoch 15/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.0102 - accuracy: 0.7914 - val_loss: 5.3543 - val_accuracy: 0.7197
# Epoch 16/50
# 17/17 [==============================] - 367s 22s/step - loss: 2.3808 - accuracy: 0.7951 - val_loss: 4.7811 - val_accuracy: 0.7500
# Epoch 17/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.6819 - accuracy: 0.7820 - val_loss: 4.9014 - val_accuracy: 0.7045
# Epoch 18/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.2954 - accuracy: 0.7820 - val_loss: 4.0367 - val_accuracy: 0.7576
# Epoch 19/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.4904 - accuracy: 0.7914 - val_loss: 4.6895 - val_accuracy: 0.7045
# Epoch 20/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.6395 - accuracy: 0.7782 - val_loss: 4.6071 - val_accuracy: 0.6894
# Epoch 21/50
# 17/17 [==============================] - 364s 21s/step - loss: 1.7938 - accuracy: 0.8195 - val_loss: 4.9318 - val_accuracy: 0.6894
# Epoch 22/50
# 17/17 [==============================] - 368s 22s/step - loss: 2.3689 - accuracy: 0.7763 - val_loss: 4.9018 - val_accuracy: 0.7348
# Epoch 23/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.7473 - accuracy: 0.8026 - val_loss: 4.6439 - val_accuracy: 0.7500
# Epoch 24/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.6903 - accuracy: 0.7838 - val_loss: 7.2398 - val_accuracy: 0.7500
# Epoch 25/50
# 17/17 [==============================] - 366s 21s/step - loss: 3.3176 - accuracy: 0.7970 - val_loss: 5.5984 - val_accuracy: 0.7273
# Epoch 26/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.6079 - accuracy: 0.7650 - val_loss: 4.6797 - val_accuracy: 0.7045
# Epoch 27/50
# 17/17 [==============================] - 363s 21s/step - loss: 2.6061 - accuracy: 0.7801 - val_loss: 4.1547 - val_accuracy: 0.7197
# Epoch 28/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.3053 - accuracy: 0.7932 - val_loss: 4.4885 - val_accuracy: 0.7045
# Epoch 29/50
# 17/17 [==============================] - 353s 21s/step - loss: 2.1348 - accuracy: 0.7932 - val_loss: 4.3044 - val_accuracy: 0.7348
# Epoch 30/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.4500 - accuracy: 0.7857 - val_loss: 4.9419 - val_accuracy: 0.7273
# Epoch 31/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.7804 - accuracy: 0.7801 - val_loss: 4.2895 - val_accuracy: 0.7197
# Epoch 32/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.4724 - accuracy: 0.7951 - val_loss: 4.5323 - val_accuracy: 0.7273
# Epoch 33/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.6701 - accuracy: 0.7838 - val_loss: 4.9498 - val_accuracy: 0.7121
# Epoch 34/50
# 17/17 [==============================] - 353s 21s/step - loss: 2.6145 - accuracy: 0.7932 - val_loss: 4.7174 - val_accuracy: 0.7348
# Epoch 35/50
# 17/17 [==============================] - 353s 21s/step - loss: 2.2439 - accuracy: 0.8120 - val_loss: 4.7285 - val_accuracy: 0.7121
# Epoch 36/50
# 17/17 [==============================] - 352s 21s/step - loss: 2.3350 - accuracy: 0.7895 - val_loss: 4.7283 - val_accuracy: 0.7121
# Epoch 37/50
# 17/17 [==============================] - 366s 21s/step - loss: 2.2862 - accuracy: 0.7838 - val_loss: 3.8907 - val_accuracy: 0.7348
# Epoch 38/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.1900 - accuracy: 0.7782 - val_loss: 4.0759 - val_accuracy: 0.7348
# Epoch 39/50
# 17/17 [==============================] - 365s 21s/step - loss: 1.9551 - accuracy: 0.7726 - val_loss: 3.9826 - val_accuracy: 0.7348
# Epoch 40/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.3416 - accuracy: 0.7989 - val_loss: 5.0620 - val_accuracy: 0.7348
# Epoch 41/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.6929 - accuracy: 0.8120 - val_loss: 4.5932 - val_accuracy: 0.7045
# Epoch 42/50
# 17/17 [==============================] - 365s 21s/step - loss: 2.0250 - accuracy: 0.7838 - val_loss: 3.7845 - val_accuracy: 0.7576
# Epoch 43/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.2688 - accuracy: 0.7932 - val_loss: 5.0933 - val_accuracy: 0.7273
# Epoch 44/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.6794 - accuracy: 0.7970 - val_loss: 5.4992 - val_accuracy: 0.6894
# Epoch 45/50
# 17/17 [==============================] - 363s 21s/step - loss: 2.9114 - accuracy: 0.7688 - val_loss: 4.8027 - val_accuracy: 0.6970
# Epoch 46/50
# 17/17 [==============================] - 364s 21s/step - loss: 2.2980 - accuracy: 0.7951 - val_loss: 4.0074 - val_accuracy: 0.6970
# Epoch 47/50
# 17/17 [==============================] - 366s 22s/step - loss: 2.2033 - accuracy: 0.7970 - val_loss: 4.0539 - val_accuracy: 0.7121
# Epoch 48/50
# 17/17 [==============================] - 364s 21s/step - loss: 1.9401 - accuracy: 0.8008 - val_loss: 3.7620 - val_accuracy: 0.7197
# Epoch 49/50
# 17/17 [==============================] - 355s 21s/step - loss: 2.1302 - accuracy: 0.8008 - val_loss: 5.1398 - val_accuracy: 0.7348
# Epoch 50/50
# 11/17 [==================>...........] - ETA: 1:40 - loss: 2.8029 - accuracy: 0.8153
